# %%
import pandas as pd
import psycopg2 as pg
import sqlalchemy as sqa
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
POSTGRES_ADDRESS = 'localhost'
POSTGRES_PORT = '5433'
POSTGRES_USERNAME = 'clinicuser'
POSTGRES_PASSWORD = 'QI~A|iD%@8cE&&y3iAp*'
POSTGRES_DBNAME = 'staging_test'

# %%
postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}' .format(username=POSTGRES_USERNAME, password=POSTGRES_PASSWORD, ipaddress=POSTGRES_ADDRESS, port=POSTGRES_PORT, dbname=POSTGRES_DBNAME))

cnx = create_engine(postgres_str)

# %%
sql_query = "select * from gtds.auswertung_diz;"
gtds_auswertung_diz = pd.read_sql_query(sql_query,cnx)

# %%
gtds_auswertung_diz.info(max_cols=300, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23904 entries, 0 to 23903
# Data columns (total 210 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   datum_der_auswertung           23904 non-null  object
#  1   satznummer                     23904 non-null  int64
#  2   patienten_id                   23904 non-null  object
#  3   anzahl_tumoren                 23904 non-null  int64
#  4   tumor_id                       23904 non-null  object
#  5   geburtsdatum                   23904 non-null  object
#  6   sterbedatum                    4356 non-null   object
#  7   sterbedatum_exakt              4343 non-null   object
#  8   geschlecht                     23904 non-null  object
#  9   plz                            23904 non-null  object
#  10  tumortod                       2073 non-null   object
#  11  autopsie                       1166 non-null   object
# ...
